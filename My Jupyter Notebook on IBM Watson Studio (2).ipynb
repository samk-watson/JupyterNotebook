# %% [markdown]
# # My Jupytor Notebook on IBM Watson Studio

# %% [markdown]
# **Sam K**
# Data Scientist

# %% [markdown]
# *I am interested in data science because Data Science is the sexiest job in America*

# %% [markdown]
# ### Sum of two numbers

# %%
5 + 5
# Out:
# 10

# %% [markdown]
# ### A table, Horizontal line, and an unordered list

# %% [markdown]
# |Column1|Column2|
# |-------|-------|
# |abc|def|

# %% [markdown]
# ---

# %% [markdown]
# * Asia
# * Africa
# * America
